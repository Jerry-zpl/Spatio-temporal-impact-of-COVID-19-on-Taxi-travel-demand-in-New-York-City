# %%
import pandas as pd

# %%
road = pd.read_table("E:\\Capstone Project\\Data\\road\\road.txt",sep = ',',thousands=',')
road
# Out:
#        OBJECTID  FID_taxi_zone_projected_csv taxi_zone_projected_borough  \
# 0             1                          102                      Queens
# 1             2                          197                      Queens
# 2             3                          102                      Queens
# 3             4                          260                       Bronx
# 4             5                          260                       Bronx
# ...         ...                          ...                         ...
# 61301     61302                           40                    Brooklyn
# 61302     61303                           40                    Brooklyn
# 61303     61304                           40                    Brooklyn
# 61304     61305                           40                    Brooklyn
# 61305     61306                           40                    Brooklyn
#
#        taxi_zone_projected_location_i  taxi_zone_projected_objectid  \
# ...

# %%
road_density = road.groupby('FID_taxi_zone_projected_csv')['Shape_Length'].sum()
road_density
# Out:
# FID_taxi_zone_projected_csv
# 2       10519.877969
# 3      180217.527873
# 4       34168.852806
# 5      207866.229165
# 6      180174.891824
#            ...
# 259     90243.990656
# 260    210162.150935
# 261    173288.315597
# 262     23572.929522
# 263     38103.983015
# Name: Shape_Length, Length: 260, dtype: float64

# %%
road_density.to_csv(r'E:\\Capstone Project\\Data\\road\\taxi_road.csv',index=True,header = 0, sep=',')
