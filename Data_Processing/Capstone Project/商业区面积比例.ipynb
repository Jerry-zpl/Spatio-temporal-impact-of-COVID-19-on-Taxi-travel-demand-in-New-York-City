# %%
import pandas as pd

# %%
com = pd.read_table("E:\\Capstone Project\\Data\\Commercial\\Commercial.txt",sep = ',',thousands=',')
com
# Out:
#       OBJECTID  FID_taxi_zone_projected_csv_csv_csv_csv_taxi_pop  \
# 0            1                                                 2
# 1            2                                                 3
# 2            3                                                 3
# 3            4                                                 3
# 4            5                                                 3
# ...        ...                                               ...
# 9645      9646                                               171
# 9646      9647                                               175
# 9647      9648                                               175
# 9648      9649                                               250
# 9649      9650                                               250
#
#      taxi_zone_projected_borough  taxi_zone_projected_location_i  \
# 0                         Queens                             2.0
# ...

# %%
commercial = com.groupby('FID_taxi_zone_projected_csv_csv_csv_csv_taxi_pop')['Shape_Area'].sum()
commercial
# Out:
# FID_taxi_zone_projected_csv_csv_csv_csv_taxi_pop
# 2      1.429243e+04
# 3      1.275832e+06
# 4      8.086662e+05
# 5      4.685744e+05
# 6      1.234670e+06
#            ...
# 258    7.343254e+05
# 259    1.976993e+06
# 260    1.801975e+06
# 261    1.965267e+06
# 263    3.808482e+05
# Name: Shape_Area, Length: 220, dtype: float64

# %%
commercial.to_csv(r'E:\\Capstone Project\\Data\\Commercial\\taxi_Commercial.csv',index=True,header = 0, sep=',')
