# %%
import gtwr
help(gtwr)
# Out:
# Help on package gtwr:
#
# NAME
#     gtwr
#
# PACKAGE CONTENTS
#     diagnosis
#     kernels
#     model
#     search
#     sel
#     setup
#     testing
#
# VERSION
#     1.0.0
#
# FILE
#     e:\anaconda\lib\site-packages\gtwr\__init__.py

# %%
help(gtwr.sel)
# Out:
# Help on module gtwr.sel in gtwr:
#
# NAME
#     gtwr.sel
#
# CLASSES
#     builtins.object
#         search_GTWRparameter
#         search_GWRparameter
#         search_TWRparameter
#
#     class search_GTWRparameter(builtins.object)
#      |  search_GTWRparameter(coords, t, y, X, kernel='exponential', fixed=False, constant=True)
#      |
#      |  Select bandwidth for GTWR model
#      |
#      |  Parameters
#      |  ----------
#      |  coords        : array-like
#      |                  n*2, collection of n sets of (x,y) coordinates of
#      |                  observatons
#      |
#      |  t             : array
#      |                  n*1, time location
#      |
#      |  y             : array
#      |                  n*1, dependent variable
#      |
#      |  X             : array
#      |                  n*k, independent variable, exlcuding the constant
#      |
#      |  kernel        : string
# ...

# %%
help(gtwr.model)
# Out:
# Help on module gtwr.model in gtwr:
#
# NAME
#     gtwr.model
#
# CLASSES
#     builtins.object
#         GTWR
#         GWR
#         Notfinal
#         Results
#         TWR
#
#     class GTWR(builtins.object)
#      |  GTWR(coords, t, y, X, bw, tau, kernel='gaussian', fixed=False, constant=True)
#      |
#      |  Geographically and Temporally Weighted Regression
#      |
#      |  Parameters
#      |  ----------
#      |  coords        : array-like
#      |                  n*2, collection of n sets of (x,y) coordinates of
#      |                  observatons
#      |
#      |  t             : array
#      |                  n*1, time location
#      |
#      |  y             : array
#      |                  n*1, dependent variable
#      |
#      |  X             : array
#      |                  n*k, independent variable, exlcuding the constant
#      |
#      |  bw            : scalar
#      |                  bandwidth value consisting of either a distance or N
# ...

# %%
help(gtwr.model.Results)
# Out:
# Help on class Results in module gtwr.model:
#
# class Results(builtins.object)
#  |  Results(coords, t, y, X, bw, tau, kernel, fixed, constant, influ, resid, predy, betas, CCT, tr_STS, model)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, coords, t, y, X, bw, tau, kernel, fixed, constant, influ, resid, predy, betas, CCT, tr_STS, model)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(gtwr.search)

# %%
df
# Out:
#      FID  shenfen                ID         lon        lat  Time  Residual  \
# 0      0        1    Beijing         116.395645  39.929986  2005 -0.004932
# 1      1        1    Beijing         116.395645  39.929986  2006 -0.048426
# 2      2        1    Beijing         116.395645  39.929986  2007 -0.024863
# 3      3        1    Beijing         116.395645  39.929986  2008 -0.092620
# 4      4        1    Beijing         116.395645  39.929986  2009 -0.093410
# ..   ...      ...               ...         ...        ...   ...       ...
# 355  355       30    Xinjiang         87.564988  43.840380  2012  0.006693
# 356  356       30    Xinjiang         87.564988  43.840380  2013  0.046058
# 357  357       30    Xinjiang         87.564988  43.840380  2014  0.017228
# 358  358       30    Xinjiang         87.564988  43.840380  2015  0.012138
# 359  359       30    Xinjiang         87.564988  43.840380  2016 -0.116267
#
# ...

# %%
# !pip install geopandas
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'E:\Anaconda\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'D:\\Temp\\pip-install-3h2itb6j\\fiona\\setup.py'"'"'; __file__='"'"'D:\\Temp\\pip-install-3h2itb6j\\fiona\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'D:\Temp\pip-pip-egg-info-r39iu7sw'
#          cwd: D:\Temp\pip-install-3h2itb6j\fiona\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
import geopandas as gpd
data = gpd.read_file("E:\\Capstone Project\\Raw_Data\\Map\\NYC Taxi Zones\\geo_export_81c0b41e-4693-4b5d-b22b-27e5a86773a0.shp")
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f2e86ebdcc90> in <module>
# ----> 1 import geopandas as gpd
#       2 data = gpd.read_file("E:\\Capstone Project\\Raw_Data\\Map\\NYC Taxi Zones\\geo_export_81c0b41e-4693-4b5d-b22b-27e5a86773a0.shp")
#       3 data
#
# ModuleNotFoundError: No module named 'geopandas'
